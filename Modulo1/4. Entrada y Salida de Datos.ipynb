# %% [markdown]
# # ENTRADA Y SALIDA DE DATOS

# %% [markdown]
# ## 1. Entrada de Información por teclado (Input)

# %% [markdown]
# En python la funcion input() nos ayudará con la tarea de capturar datos del usuario

# %%
# input por defecto nos devuelve datos de tipo texto
# SHIFT + ENTER -> EJECUTAR CELDA ACTUAL Y IR A LA SIGUIENTE CELDA
# CONTROL + ENTER -> EJECUTAR CELDA ACTUAL
numero = input("Introduce un número decimal con punto: ")
numero
# Out:
# '100'

# %%
type(numero)
# Out:
# str

# %%
numero = float(numero)
numero
# Out:
# 50.8

# %%
# tab -> autocompleta texto
numero
# Out:
# 50.8

# %%
type(numero)
# Out:
# float

# %%
# shift + tab -> documentacion de la funcion que estoy empleando
decimal = float(input("Ingrese un valor numerico:  "))
#decimal
print(decimal)
# Out:
# 100.0

# %%
# CUIDADO -> recordar que input retorna un str

edad = input('ingrese su edad')

#  aumentando la edad en 2
edad + 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       1 # CUIDADO -> recordar que input retorna un str
#       3 edad = input('ingrese su edad')
# ----> 5 edad + 2
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# ## 2. Entrada de datos por Argumentos

# %% [markdown]
# Para poder enviar información a un script y manejarla, tenemos que utilizar la librería de sistema [sys](https://www.geeksforgeeks.org/how-to-use-sys-argv-in-python/). En ella encontraremos la lista argv que almacena los argumentos enviados al script.

# %%
# Hacer en vscode
import sys
print(sys.argv)
# Out:
# ['/home/codespace/.local/lib/python3.10/site-packages/ipykernel_launcher.py', '--f=/home/codespace/.local/share/jupyter/runtime/kernel-v2-8256zmZhmAXPswiX.json']

# %% [markdown]
# ## 3. Salida de información (Output)

# %% [markdown]
# La función print nos ayudará a realizar salidas de información

# %%
print('hola')

# %%
## Nota -> Agregando una variable a la cadena de impresión

suma = 3 +7 # int

# Opcion 1
print("El valor de la suma es "+  str(suma)) # str(suma) -> concadenacion solo sirve para strings

# Opcion 2 -> Mejor opcion
print(f"El valor de la suma es: {suma}") # formatea el numero a texto

# opcion 3 -> Otra buena Opcion
print("El valor de la suma es: {}".format(suma))
# Out:
# El valor de la suma es 10
# El valor de la suma es: 10
# El valor de la suma es: 10

# %%
'Hola ' + str(2)
# Out:
# 'Hola 2'

# %% [markdown]
# # EJERCICIOS

# %% [markdown]
# #### 1. Realiza un programa que lea 2 números por teclado y determine los siguientes aspectos (es suficiene con mostrar True o False):
#
# - Si los dos números son iguales
# - Si los dos números son diferentes
# - Si el primero es mayor que el segundo
# - Si el segundo es mayor o igual que el primero

# %%
# Leer dos números por teclado
numero1 = float(input("Ingrese el primer número: "))
numero2 = float(input("Ingrese el segundo número: "))

# Comparar los números y determinar los aspectos
son_iguales = numero1 == numero2
son_diferentes = numero1 != numero2
primero_mayor_que_segundo = numero1 > numero2
segundo_mayor_o_igual_que_primero = numero2 >= numero1

# Mostrar los resultados
print(numero1,numero2)
print("Los dos números son iguales:", son_iguales)
print("Los dos números son diferentes:", son_diferentes)
print("El primero es mayor que el segundo:", primero_mayor_que_segundo)
print("El segundo es mayor o igual que el primero:", segundo_mayor_o_igual_que_primero)
# Out:
# 10.0 8.0
# Los dos números son iguales: False
# Los dos números son diferentes: True
# El primero es mayor que el segundo: True
# El segundo es mayor o igual que el primero: False

# %% [markdown]
# ### 2.
# Una panadería vende barras de pan a 3.49€ cada una. El pan que no es el día tiene un descuento del 60%. Escribir un programa que comience leyendo el número de barras vendidas que no son del día. Después el programa debe mostrar el precio habitual de una barra de pan, el descuento que se le hace por no ser fresca y el coste final total.

# %%
# Precio de una barra de pan
precio_normal = 3.49  # en euros

# Descuento por no ser del día (60%)
descuento = 0.60

# Leer el número de barras vendidas que no son del día
barras_no_frescas = int(input("Ingrese el número de barras vendidas que no son del día: "))

# Calcular el precio final total
precio_descuento = precio_normal * descuento
coste_final = barras_no_frescas * (precio_normal-precio_descuento)

# Mostrar los resultados
print("Precio habitual de una barra de pan:", precio_normal, "€")
print("Descuento por no ser fresca:", descuento * 100, "%")
print("Coste final total:", coste_final, "€")
# Out:
# Precio habitual de una barra de pan: 3.49 €
# Descuento por no ser fresca: 60.0 %
# Coste final total: 1.3960000000000004 €

# %% [markdown]
# ### 3.
# Escribir un programa que pida al usuario su peso (en kg) y estatura (en metros), calcule el índice de masa corporal y lo almacene en una variable, y muestre por pantalla la frase Tu índice de masa corporal es <imc> donde <imc> es el índice de masa corporal calculado redondeado con dos decimales.

# %%
# Solicitar al usuario su peso en kg y estatura en metros
peso = float(input("Ingrese su peso en kg: "))
estatura = float(input("Ingrese su estatura en metros: "))

# Calcular el índice de masa corporal (IMC)
imc = peso / (estatura ** 2)


# Mostrar el índice de masa corporal redondeado con dos decimales
print("Tu índice de masa corporal es:", imc,"donde",round(imc, 2),"es el indice de masa corporal calculado redondeado con 2 deciamles")
# Out:
# Tu índice de masa corporal es: 35.83266147093075 donde 35.83 es el indice de masa corporal calculado redondeado con 2 deciamles

# %% [markdown]
# 4.
#
# Escriba un programa python que solicite un texto por teclado y convierta todos los carácteres en minuscula.
# Ejemplo
#
# texto ingresado -> "Hola AmigOs"
# resultado -> "hola amigos"

# %%
#Solicitar al usuario ingresar un texto
texto = input("Ingrese un texto: ")

# Convertir el texto a minúsculas
texto_minusculas = texto.lower()

# Mostrar el texto en minúsculas
print("Texto en minúsculas:", texto_minusculas)
# Out:
# Texto en minúsculas: hola amiffo
